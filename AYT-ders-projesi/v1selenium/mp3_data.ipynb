# %% [markdown]
# Veriyi spotify arayüzü üzerinden şarkı seçerek topladık.Elimizde 60 şarkı bulunmakta.

# %% [markdown]
# Seçmesi sırasında birden fazla kişi ve birden fazla alan kullanılarak seçim yapıldı.

# %%
import pandas as pd


dosya_yolu = 'spotify_case.xlsx' 



try:
    df = pd.read_excel(dosya_yolu)
    print(f"'{dosya_yolu}' dosyası başarıyla okundu.")
    
    print("\n--- Çekilen Verinin İlk 30 Satırı (df.head(30)) ---")
    
    
    display(df.head(30)) 

except FileNotFoundError:
    print(f"HATA: '{dosya_yolu}' bulunamadı. Lütfen dosya adını ve yolunu kontrol edin.")
except Exception as e:
    print(f"Okuma sırasında bir hata oluştu: {e}")
# Out:
# 'spotify_case.xlsx' dosyası başarıyla okundu.
#
# --- Çekilen Verinin İlk 30 Satırı (df.head(30)) ---
#    Senaryo Numarası Test Suite Kapsamı Önem Derecesi  \
# 0            TC_OO1     Mini Regresyon        Medium
# 1            TC_OO2     Mini Regresyon        Medium
# 2            TC_OO3     Mini Regresyon        Medium
# 3            TC_OO4     Mini Regresyon        Medium
# 4            TC_OO5     Mini Regresyon        Medium
# 5            TC_OO6     Mini Regresyon        Medium
# 6            TC_OO7     Mini Regresyon        Medium
# 7            TC_OO8     Mini Regresyon        Medium
# 8            TC_OO9     Mini Regresyon        Medium
# 9           TC_OO10     Mini Regresyon        Medium
# 10          TC_OO11     Mini Regresyon        Medium
# 11          TC_OO12     Mini Regresyon        Medium
# 12          TC_OO13     Mini Regresyon        Medium
# 13          TC_OO14     Mini Regresyon        Medium
# 14          TC_OO15     Mini Regresyon        Medium
# ...
