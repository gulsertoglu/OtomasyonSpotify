# %%
import json
import pandas as pd

path = "data/sessions/session_20251203_181605_Bu_Aşk_Fazla_Sana.json"

with open(path, "r", encoding="utf-8") as f:
    session = json.load(f)

tracks = session["tracks"]

df = pd.json_normalize(tracks)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       2 import pandas as pd
#       4 path = "data/sessions/session_20251203_181605_Bu_Aşk_Fazla_Sana.json"
# ----> 6 with open(path, "r", encoding="utf-8") as f:
#       7     session = json.load(f)
#       9 tracks = session["tracks"]
#
# File c:\Users\memir\OneDrive\Documents\GitHub\OtomasyonSpotify\.venv\Lib\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/sessions/session_20251203_181605_Bu_Aşk_Fazla_Sana.json'

# %%
df[["order_index", "name", "artists", "popularity", "artist_genres_main"]]

# %%
df["artists_str"] = df["artists"].apply(lambda xs: ", ".join(xs))
df[["order_index", "name", "artists_str", "popularity"]]

# %%
df["release_date"] = pd.to_datetime(df["release_date"], errors="coerce")
df["year"] = df["release_date"].dt.year
df[["name", "year", "popularity"]]

# %%
from collections import Counter

all_genres = []
for g_list in df["artist_genres_main"]:
    if isinstance(g_list, list):
        all_genres.extend(g_list)

Counter(all_genres)

# %%
analysis_path = "data/analysis/analysis_20251203_212442_session_20251203_181605_Bu_Aşk_Fazla_Sana.json"

with open(analysis_path, "r", encoding="utf-8") as f:
    analysis = json.load(f)

analysis["score"], analysis["analysis_text"][:200]
